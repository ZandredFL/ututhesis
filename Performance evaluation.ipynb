# %%
import matplotlib.pyplot as plt

performance_metrics = {
    'accuracy': [0.8831223628691983, 0.8742616033755274, 0.8721518987341772, 0.8734177215189873, 0.8556962025316455, 0.8611814345991562, 0.8531645569620254, 0.8426160337552743, 0.8683544303797468, 0.8734177215189873, 0.870464135021097, 0.8734177215189872, 0.8789029535864978, 0.8599156118143461, 0.8767932489451477],
    'precision': [0.8865475345480472, 0.8747122220672743, 0.8707979222097576, 0.873914253942323, 0.8741301937038646, 0.8719487605495917, 0.8675146256986667, 0.8621227829898748, 0.8801894437197844, 0.8834610996184298, 0.8804722774326621, 0.8822012847323142, 0.880241676457825, 0.8739425714543596, 0.8858604485662609],
    'recall': [0.8831223628691983, 0.8742616033755274, 0.8721518987341772, 0.8734177215189873, 0.8556962025316455, 0.8611814345991562, 0.8531645569620254, 0.8426160337552743, 0.8683544303797468, 0.8734177215189873, 0.870464135021097, 0.8734177215189872, 0.8789029535864978, 0.8599156118143461, 0.8767932489451477],
    'f1_score': [0.8744911075771533, 0.8675481515576605, 0.8649141044723405, 0.8667321112874834, 0.858073691666949, 0.8629855383807635, 0.855831474372768, 0.8463887342947611, 0.8669082350572015, 0.8724540477286953, 0.8704663526679305, 0.8731084994614641, 0.8722683403785476, 0.8627461362411666, 0.8763365810661036],
    'roc_auc': [0.884543626807066, 0.8877644282113468, 0.8853129014693101, 0.8876596945104422, 0.8945352856943247, 0.8919224685092912, 0.8879292586709557, 0.8810364116194341, 0.895261016221632, 0.8917293004771325, 0.906085757443402, 0.8976376921403757, 0.9015546475512612, 0.8982646134053429, 0.9106162803621765]
}

# Generate x-axis values for the runs
runs = range(1, 16)

# Plotting all performance metrics on the same graph
plt.plot(runs, performance_metrics['accuracy'], label='Accuracy', marker='o')
plt.plot(runs, performance_metrics['precision'], label='Precision', marker='s')
plt.plot(runs, performance_metrics['recall'], label='Recall', marker='^')
plt.plot(runs, performance_metrics['f1_score'], label='F1-score', marker='d')
plt.plot(runs, performance_metrics['roc_auc'], label='ROC AUC', marker='x')

plt.xlabel('Runs')
plt.ylabel('Value')
plt.title('Performance Metrics Comparison')
plt.legend()
plt.xticks(runs)  # Set the x-axis ticks to be the runs
plt.grid(True)
plt.show()

# %%
performance_metrics = {
    'KNN': {'accuracy': 0.8379746835443038, 'precision': 0.8516070939805079, 'recall': 0.8379746835443038, 'f1_score': 0.8397836431113292, 'roc_auc': 0.8622974388181331},
    'Decision Tree': {'accuracy': 0.8594936708860759, 'precision': 0.8709033355240134, 'recall': 0.8594936708860759, 'f1_score': 0.8599468178185944, 'roc_auc': 0.8577004698814596},
    'Random Forest': {'accuracy': 0.8725738396624472, 'precision': 0.8801708140812637, 'recall': 0.8725738396624472, 'f1_score': 0.8717008274765977, 'roc_auc': 0.8958429251823412},
    'XGBoost': {'accuracy': 0.870464135021097, 'precision': 0.8804722774326621, 'recall': 0.870464135021097, 'f1_score': 0.8704663526679305, 'roc_auc': 0.906085757443402}
}

# Iterate over each model
for model, metrics in performance_metrics.items():
    # Generate x-axis values for the metrics
    metrics_keys = list(metrics.keys())
    values = list(metrics.values())

    # Plotting all performance metrics on the same graph
    plt.plot(metrics_keys, values, label=model, marker='o')

plt.xlabel('Performance Metrics')
plt.ylabel('Value')
plt.title('Models Comparison')
plt.legend()
plt.grid(True)
plt.show()
